# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #CPI

# %%
df = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/France_CPI_Electricity.csv")
df.isnull().values.sum()
df.head()
# Out:
#          DATE  CP0450FRM086NEST
# 0  2006-01-01             70.63
# 1  2006-02-01             70.88
# 2  2006-03-01             71.11
# 3  2006-04-01             73.06
# 4  2006-05-01             73.73

# %%
df['DATE'] = pd.to_datetime(df['DATE'],format="%Y-%m-%d")

# %%
df=df.query("DATE>=2007 and DATE<='2010-11'")

# %%
df.columns= ['Date','CPI']
df[['Date','CPI']].to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YM_Clean_France_CPI_Electricity.csv",index=None)

# %% [markdown]
# # Main File - Power Consumption

# %%
df =pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/UCI_Power_Consumption_Dataset.txt",sep=';')
df.isnull().values.sum()
df
# Out:
# <ipython-input-31-afa16d433e69>:1: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/UCI_Power_Consumption_Dataset.txt",sep=';')
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# ...

# %%
df['Global_active_power']= df['Global_active_power'].interpolate(option='spline')
df['Global_reactive_power']= df['Global_reactive_power'].interpolate(option='spline')
df['Voltage']= df['Voltage'].interpolate(option='spline')
df['Global_intensity']= df['Global_intensity'].interpolate(option='spline')
df['Sub_metering_1']= df['Sub_metering_1'].interpolate(option='spline')
df['Sub_metering_2']= df['Sub_metering_2'].interpolate(option='spline')
df['Sub_metering_3']= df['Sub_metering_3'].interpolate(option='spline')

# %%
df.isnull().values.sum()
df['Date']=df['Date']+' '+df['Time']
df
# Out:
#                         Date      Time Global_active_power  \
# 0        16/12/2006 17:24:00  17:24:00               4.216
# 1        16/12/2006 17:25:00  17:25:00               5.360
# 2        16/12/2006 17:26:00  17:26:00               5.374
# 3        16/12/2006 17:27:00  17:27:00               5.388
# 4        16/12/2006 17:28:00  17:28:00               3.666
# ...                      ...       ...                 ...
# 2075254  26/11/2010 20:58:00  20:58:00               0.946
# 2075255  26/11/2010 20:59:00  20:59:00               0.944
# 2075256  26/11/2010 21:00:00  21:00:00               0.938
# 2075257  26/11/2010 21:01:00  21:01:00               0.934
# 2075258  26/11/2010 21:02:00  21:02:00               0.932
#
#         Global_reactive_power  Voltage Global_intensity Sub_metering_1  \
# 0                       0.418  234.840           18.400          0.000
# 1                       0.436  233.630           23.000          0.000
# ...

# %%
df.query('Date>=2007 and Global_active_power=="?"')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-01120124cfdd> in <cell line: 1>()
# ----> 1 df.query('Date>=2007 and Global_active_power=="?"')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4472         kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473         kwargs["target"] = None
# -> 4474         res = self.eval(expr, **kwargs)
#    4475
#    4476         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format="%d/%m/%Y %H:%M:%S")
df=df.query('Date>=2007')
df

# %%
df.to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMH_Clean_UCI_Power_Consumption_Dataset.csv",index=None)

# %% [markdown]
# #Temp_ISD

# %%
df2007 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/France_Temp_ISD/ISD_2007.csv")
df2008 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/France_Temp_ISD/ISD_2008.csv")
df2009 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/France_Temp_ISD/ISD_2009.csv")
df2010 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/France_Temp_ISD/ISD_2010.csv")

# %%
df2010.head()

# %%
df2010['DATE'] = pd.to_datetime(df2010['DATE'],format='%Y-%m-%dT%H:%M:%S')
df2010=df2010.query("DATE<='2010-11-26'")

# %%
frames = [df2007, df2008,df2009,df2010]
df = pd.concat(frames)
df.head()

# %%
df.to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMH_Clean_TempISD.csv")

# %% [markdown]
# #CCI

# %%
df_cci = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/CCI_monthly_values.csv",sep=';')
df_cci=df_cci.iloc[3:,:2]
df_cci.columns = ['Date', 'CCI']
df_cci=df_cci.query("Date>='2007' and Date<='2010-11'")
df_cci[['Date', 'CCI']].to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YM_Clean_CCI.csv",index=False)
df_cci.head()

# %% [markdown]
# #Google Trends

# %%
df1 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/GT1.csv")
df2 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/GT2.csv")
df3 = pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/GT3.csv")

# %%
df1['Week'] = pd.to_datetime(df1['Week'],format='%m/%d/%y')
df1.columns = ['Date', 'GT1_Hits']
df1[['Date', 'GT1_Hits']].to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMW_Clean_GoogleTrends1.csv",index=False)
df1.head()

# %%
df2['Week'] = pd.to_datetime(df2['Week'],format='%m/%d/%y')
df2
df2.columns = ['Date', 'GT2_Hits']
df2[['Date', 'GT2_Hits']].to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMW_Clean_GoogleTrends2.csv",index=False)
df2.head()

# %%
df3['Week'] = pd.to_datetime(df3['Week'],format='%m/%d/%y')
df3.columns = ['Date', 'GT3_Hits']
df3[['Date', 'GT3_Hits']].to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMW_Clean_GoogleTrends3.csv",index=False)
df3.head()

# %% [markdown]
# #Temp

# %%
df=pd.read_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/raw/dataexport_20231114T035544.csv",skiprows=9)
df.head()

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'],format='%Y-%m-%dT%H:%M:%S')
df.columns = ['Date', 'Temperature','Precipitation', 'Humidity','Sunshine']
df.head()
#df.to_csv("/content/drive/MyDrive/BDA 696 Project/Datasets/processsed/YMH_Weather.csv",index=False)
